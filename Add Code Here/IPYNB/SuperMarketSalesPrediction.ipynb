# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/SuperMarket.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   Invoice ID    City Customer type  Gender         Product line  \
# 0         856  770-42-8960  Mumbai        Normal    Male   Food and beverages
# 1         567  651-88-7328  Mumbai        Normal  Female  Fashion accessories
# 2         245  530-90-9855  Mumbai        Member    Male   Home and lifestyle
# 3         696  182-52-7000  Mumbai        Member  Female    Sports and travel
# 4         523  133-14-7229  Mumbai        Normal    Male    Health and beauty
#
#    Unit price  Quantity  Tax 5%    Total        Date   Time  Payment    cogs  \
# 0       21.12         8   8.448  177.408  2019-01-01  19:31     Cash  168.96
# 1       65.74         9  29.583  621.243  2019-01-01  13:55     Cash  591.66
# 2       47.59         8  19.036  399.756  2019-01-01  14:47     Cash  380.72
# 3       27.04         4   5.408  113.568  2019-01-01  20:26  Ewallet  108.16
# 4       62.87         2   6.287  132.027  2019-01-01  11:43     Cash  125.74
#
# ...

# %%
sum_month1_Sports=0
for i in range(len(df['Quantity'])):
    a=df['Date'][i]
    
    if a[-4]=='1' and df['Product_line'][i]=='Sports and travel':
      sum_month1_Sports+=df['Quantity'][i]    
        #print(a[-4])
    else:
        pass
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Product_line'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
print(sum_month1_Sports)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6a79fc99077c> in <module>()
# ----> 1 print(sum_month1_Sports)
#
# NameError: name 'sum_month1_Sports' is not defined

# %%
df.tail()
# Out:
#      Unnamed: 0   Invoice ID    City Customer type  Gender  \
# 995         158  743-04-1105  Mumbai        Member    Male
# 996         881  115-38-7388  Mumbai        Member  Female
# 997         963  364-34-2972  Mumbai        Member    Male
# 998         937  361-85-2571  Mumbai        Normal  Female
# 999         474  676-39-6028  Mumbai        Member  Female
#
#                Product line  Unit price  Quantity  Tax 5%    Total  \
# 995       Health and beauty       97.22         9  43.749  918.729
# 996     Fashion accessories       10.18         8   4.072   85.512
# 997  Electronic accessories       96.82         3  14.523  304.983
# 998       Sports and travel       89.48         5  22.370  469.770
# 999  Electronic accessories       64.44         5  16.110  338.310
#
#            Date   Time      Payment    cogs  gross margin percentage  \
# 995  2019-03-30  14:43      Ewallet  874.98                 4.761905
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0   Unit price     Quantity       Tax 5%        Total  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean    499.500000    55.672130     5.510000    15.379369   322.966749
# std     288.819436    26.494628     2.923431    11.708825   245.885335
# min       0.000000    10.080000     1.000000     0.508500    10.678500
# 25%     249.750000    32.875000     3.000000     5.924875   124.422375
# 50%     499.500000    55.230000     5.000000    12.088000   253.848000
# 75%     749.250000    77.935000     8.000000    22.445250   471.350250
# max     999.000000    99.960000    10.000000    49.650000  1042.650000
#
#              cogs  gross margin percentage  gross income      Rating
# count  1000.00000              1000.000000   1000.000000  1000.00000
# mean    307.58738                 4.761905     15.379369     6.97270
# std     234.17651                 0.000000     11.708825     1.71858
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# Invoice ID                 0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               1000 non-null   int64
#  1   Invoice ID               1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.rename(columns = {'Unit price':'Unit_price', 'Product line':'Product_line','gross margin percentage':'gross_margin_percentage','gross income':'gross_income','Customer type':'Customer_type','Invoice ID':'Invoice_ID'}, inplace = True)

# %%
df.Product_line.value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product_line, dtype: int64

# %%
import matplotlib.pyplot as plt

df.plot(x="Product_line",y=["gross_margin_percentage","gross_income"])
plt.show()

# %%
df.corr()
# Out:
#                          Unnamed: 0  Unit_price  Quantity    Tax 5%     Total  \
# Unnamed: 0                 1.000000   -0.003676 -0.066186 -0.051277 -0.051277
# Unit_price                -0.003676    1.000000  0.010778  0.633962  0.633962
# Quantity                  -0.066186    0.010778  1.000000  0.705510  0.705510
# Tax 5%                    -0.051277    0.633962  0.705510  1.000000  1.000000
# Total                     -0.051277    0.633962  0.705510  1.000000  1.000000
# cogs                      -0.051277    0.633962  0.705510  1.000000  1.000000
# gross_margin_percentage         NaN         NaN       NaN       NaN       NaN
# gross_income              -0.051277    0.633962  0.705510  1.000000  1.000000
# Rating                    -0.026995   -0.008778 -0.015815 -0.036442 -0.036442
#
#                              cogs  gross_margin_percentage  gross_income  \
# Unnamed: 0              -0.051277                      NaN     -0.051277
# ...

# %%
import seaborn as sns
sns.heatmap(df.corr(), annot=True)

# %%
df['Quantity'] = pd.to_numeric(df['Quantity'], errors='coerce').astype('Float64')

# %%
df2=df.copy()

# %%
del df2['Date']

# %%
del df2['Payment']
del df2['Time']

# %%
df2
# Out:
#      Unnamed: 0   Invoice_ID    City Customer_type  Gender  \
# 0           856  770-42-8960  Mumbai        Normal    Male
# 1           567  651-88-7328  Mumbai        Normal  Female
# 2           245  530-90-9855  Mumbai        Member    Male
# 3           696  182-52-7000  Mumbai        Member  Female
# 4           523  133-14-7229  Mumbai        Normal    Male
# ..          ...          ...     ...           ...     ...
# 995         158  743-04-1105  Mumbai        Member    Male
# 996         881  115-38-7388  Mumbai        Member  Female
# 997         963  364-34-2972  Mumbai        Member    Male
# 998         937  361-85-2571  Mumbai        Normal  Female
# 999         474  676-39-6028  Mumbai        Member  Female
#
#                Product_line  Unit_price  Quantity  Tax 5%    Total    cogs  \
# 0        Food and beverages       21.12       8.0   8.448  177.408  168.96
# 1       Fashion accessories       65.74       9.0  29.583  621.243  591.66
# ...

# %%
x=df2.iloc[:,6:9].values

# %%
print(x)
# Out:
# [[21.12 8.0 8.448]
#  [65.74 9.0 29.583]
#  [47.59 8.0 19.036]
#  ...
#  [96.82 3.0 14.523]
#  [89.48 5.0 22.37]
#  [64.44 5.0 16.11]]

# %%
from sklearn import preprocessing
min_max_scaler=preprocessing.MinMaxScaler(feature_range=(0,1))
x_after_min_max=min_max_scaler.fit_transform(x)

# %%
print(x_after_min_max)
# Out:
# [[0.12283044 0.77777778 0.16156405]
#  [0.61927014 0.88888889 0.59164861]
#  [0.41733422 0.77777778 0.37702349]
#  ...
#  [0.96506453 0.22222222 0.28518665]
#  [0.88340009 0.44444444 0.44486839]
#  [0.60480641 0.44444444 0.31748115]]

# %%
y=df2.iloc[:,15:17].values

# %%
print(y)
# Out:
# []

# %%
from sklearn import preprocessing
min_max_scaler=preprocessing.MinMaxScaler(feature_range=(0,1))
y_after_min_max=min_max_scaler.fit_transform(x,y)

# %%
print(y_after_min_max)
# Out:
# [[0.12283044 0.77777778 0.16156405]
#  [0.61927014 0.88888889 0.59164861]
#  [0.41733422 0.77777778 0.37702349]
#  ...
#  [0.96506453 0.22222222 0.28518665]
#  [0.88340009 0.44444444 0.44486839]
#  [0.60480641 0.44444444 0.31748115]]

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
pca.fit(x)
x_pca=pca.transform(x)
x_pca
# Out:
# array([[-35.01235152,  -4.42322655],
#        [ 13.89936312, -11.04918816],
#        [ -6.58724435,  -6.40333185],
#        ...,
#        [ 38.96950446,  13.43104926],
#        [ 34.34119971,   3.57058084],
#        [  8.57769765,   2.02300203]])

# %%
del df2['gross_margin_percentage']
del df2['Customer_type']
del df2['Gender']
del df2['City']
#del df2['Product_line']

# %%
del df2['Invoice_ID']

# %%
df2
# Out:
#      Unnamed: 0            Product_line  Unit_price  Quantity  Tax 5%  \
# 0           856      Food and beverages       21.12       8.0   8.448
# 1           567     Fashion accessories       65.74       9.0  29.583
# 2           245      Home and lifestyle       47.59       8.0  19.036
# 3           696       Sports and travel       27.04       4.0   5.408
# 4           523       Health and beauty       62.87       2.0   6.287
# ..          ...                     ...         ...       ...     ...
# 995         158       Health and beauty       97.22       9.0  43.749
# 996         881     Fashion accessories       10.18       8.0   4.072
# 997         963  Electronic accessories       96.82       3.0  14.523
# 998         937       Sports and travel       89.48       5.0  22.370
# 999         474  Electronic accessories       64.44       5.0  16.110
#
#        Total    cogs  gross_income  Rating
# 0    177.408  168.96         8.448     6.3
# ...

# %%
del df2['Unnamed: 0']

# %%
x1=df2.iloc[:,0:6]

# %%
x1
# Out:
#                Product_line  Unit_price  Quantity  Tax 5%    Total    cogs
# 0        Food and beverages       21.12       8.0   8.448  177.408  168.96
# 1       Fashion accessories       65.74       9.0  29.583  621.243  591.66
# 2        Home and lifestyle       47.59       8.0  19.036  399.756  380.72
# 3         Sports and travel       27.04       4.0   5.408  113.568  108.16
# 4         Health and beauty       62.87       2.0   6.287  132.027  125.74
# ..                      ...         ...       ...     ...      ...     ...
# 995       Health and beauty       97.22       9.0  43.749  918.729  874.98
# 996     Fashion accessories       10.18       8.0   4.072   85.512   81.44
# 997  Electronic accessories       96.82       3.0  14.523  304.983  290.46
# 998       Sports and travel       89.48       5.0  22.370  469.770  447.40
# 999  Electronic accessories       64.44       5.0  16.110  338.310  322.20
#
# [1000 rows x 6 columns]

# %%
x1 = pd.get_dummies(x1, columns=['Product_line'])

# %%
df2.head()
# Out:
#           Product_line  Unit_price  Quantity  Tax 5%    Total    cogs  \
# 0   Food and beverages       21.12       8.0   8.448  177.408  168.96
# 1  Fashion accessories       65.74       9.0  29.583  621.243  591.66
# 2   Home and lifestyle       47.59       8.0  19.036  399.756  380.72
# 3    Sports and travel       27.04       4.0   5.408  113.568  108.16
# 4    Health and beauty       62.87       2.0   6.287  132.027  125.74
#
#    gross_income  Rating
# 0         8.448     6.3
# 1        29.583     7.7
# 2        19.036     5.7
# 3         5.408     6.9
# 4         6.287     5.0

# %%
x1
# Out:
#      Unit_price  Quantity  Tax 5%    Total    cogs  \
# 0         21.12       8.0   8.448  177.408  168.96
# 1         65.74       9.0  29.583  621.243  591.66
# 2         47.59       8.0  19.036  399.756  380.72
# 3         27.04       4.0   5.408  113.568  108.16
# 4         62.87       2.0   6.287  132.027  125.74
# ..          ...       ...     ...      ...     ...
# 995       97.22       9.0  43.749  918.729  874.98
# 996       10.18       8.0   4.072   85.512   81.44
# 997       96.82       3.0  14.523  304.983  290.46
# 998       89.48       5.0  22.370  469.770  447.40
# 999       64.44       5.0  16.110  338.310  322.20
#
#      Product_line_Electronic accessories  Product_line_Fashion accessories  \
# 0                                      0                                 0
# 1                                      0                                 1
# 2                                      0                                 0
# ...

# %%
x1=x1.drop(labels="Total",axis=1)

# %%
x1=x1.drop(labels="cogs",axis=1)

# %%
x1=x1.drop(labels="Tax 5%",axis=1)

# %%
x1
# Out:
#      Unit_price  Quantity  Product_line_Electronic accessories  \
# 0            21         8                                    0
# 1            65         9                                    0
# 2            47         8                                    0
# 3            27         4                                    0
# 4            62         2                                    0
# ..          ...       ...                                  ...
# 995          97         9                                    0
# 996          10         8                                    0
# 997          96         3                                    1
# 998          89         5                                    0
# 999          64         5                                    1
#
#      Product_line_Fashion accessories  Product_line_Food and beverages  \
# 0                                   0                                1
# ...

# %%
x1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Unit_price                           1000 non-null   Int64
#  1   Quantity                             1000 non-null   Int64
#  2   Product_line_Electronic accessories  1000 non-null   uint8
#  3   Product_line_Fashion accessories     1000 non-null   uint8
#  4   Product_line_Food and beverages      1000 non-null   uint8
#  5   Product_line_Health and beauty       1000 non-null   uint8
#  6   Product_line_Home and lifestyle      1000 non-null   uint8
#  7   Product_line_Sports and travel       1000 non-null   uint8
# dtypes: Int64(2), uint8(6)
# memory usage: 23.6 KB

# %%
x1.rename(columns={'Product_line_Electronic accessories':'Product_line_Electronic_accessories','Product_line_Fashion accessories':'Product_line_Fashion_accessories','Product_line_Food and beverages':'Product_line_Food_and_beverages','Product_line_Health and beauty':'Product_line_Health_and_beauty','Product_line_Home and lifestyle':'Product_line_Home_and_lifestyle','Product_line_Sports and travel':'Product_line_Sports_and_travel'})
# Out:
#      Unit_price  Quantity  Product_line_Electronic_accessories  \
# 0            21         8                                    0
# 1            65         9                                    0
# 2            47         8                                    0
# 3            27         4                                    0
# 4            62         2                                    0
# ..          ...       ...                                  ...
# 995          97         9                                    0
# 996          10         8                                    0
# 997          96         3                                    1
# 998          89         5                                    0
# 999          64         5                                    1
#
#      Product_line_Fashion_accessories  Product_line_Food_and_beverages  \
# 0                                   0                                1
# ...

# %%
x1['Unit_price'] = np.floor(pd.to_numeric(df['Unit_price'], errors='coerce')).astype('Int64')
x1['Quantity'] = np.floor(pd.to_numeric(df['Quantity'], errors='coerce')).astype('Int64')

# %%
y1=df.gross_income

# %%
print(y1)
# Out:
# 0       8.448
# 1      29.583
# 2      19.036
# 3       5.408
# 4       6.287
#         ...
# 995    43.749
# 996     4.072
# 997    14.523
# 998    22.370
# 999    16.110
# Name: gross_income, Length: 1000, dtype: float64

# %%
x1
# Out:
#      Unit_price  Quantity  Product_line_Electronic accessories  \
# 0            21         8                                    0
# 1            65         9                                    0
# 2            47         8                                    0
# 3            27         4                                    0
# 4            62         2                                    0
# ..          ...       ...                                  ...
# 995          97         9                                    0
# 996          10         8                                    0
# 997          96         3                                    1
# 998          89         5                                    0
# 999          64         5                                    1
#
#      Product_line_Fashion accessories  Product_line_Food and beverages  \
# 0                                   0                                1
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.2,random_state=0)

# %%
x_train
# Out:
#      Unit_price  Quantity  Product_line_Electronic accessories  \
# 687          20         8                                    1
# 500          13         6                                    0
# 332          93         3                                    1
# 979          38         3                                    0
# 817          56         1                                    0
# ..          ...       ...                                  ...
# 835          77        10                                    0
# 192          12         8                                    1
# 629          90         6                                    1
# 559          64         7                                    0
# 684          51         5                                    1
#
#      Product_line_Fashion accessories  Product_line_Food and beverages  \
# 687                                 0                                0
# ...

# %%
y_test
# Out:
# 993    21.0630
# 859    15.4940
# 298    24.5130
# 553     1.4760
# 672    11.0115
#         ...
# 679     4.0530
# 722    24.8100
# 215     4.9065
# 653     9.3200
# 150     3.4290
# Name: gross_income, Length: 200, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# -15.401580600752466
# [ 2.79727892e-01  2.77960514e+00 -5.69132241e-02 -9.84432305e-02
#  -4.92331838e-02 -1.38999066e-01  3.44604625e-01 -1.01592062e-03]

# %%
y_pred=regressor.predict(x_test)

# %%
y_pred
# Out:
# array([20.71800364, 17.6004923 , 23.88477634, -6.06517889, 13.2183719 ,
#        17.45103482, 24.03939079, 16.37746455, 31.43262535, 11.72620656,
#         4.61121929, 36.97896593, -5.68569138,  3.15337604, 17.56994721,
#         6.3985053 ,  9.42249077, 26.17081674, 21.76622008, 14.97882509,
#         3.95200389, 15.66007083, 34.3893228 , 16.8548345 , 17.04103651,
#         6.67343072, 25.73543192, 28.47453253,  9.84396341, 27.69873544,
#        31.6918035 , 14.6990972 , -1.76950088, 22.938153  , 25.70008436,
#         9.33752897, 24.13915041, 15.14251655, 27.05821929, 37.43098205,
#        -4.32858192,  9.53409622, 17.23719797, 34.19936079, 18.85348558,
#        14.39551308, -0.8744199 , 26.5746156 , 29.61627485, 17.09293176,
#         2.09366826,  7.44672174, -8.52450031, -9.82571246, 13.03647711,
#        30.62878924,  5.18216642, 16.83087765, 13.46275222, -1.57185883,
#        24.18217801,  7.38464199, 39.87268099, 18.65351121, 15.16019033,
# ...

# %%
d=pd.DataFrame({'Actual':[y_test],'Predicted':[y_pred]})
d
# Out:
#                                               Actual  \
# 0  993    21.0630
# 859    15.4940
# 298    24.5130
# 5...
#
#                                            Predicted
# 0  [20.718003642958962, 17.6004922976949, 23.8847...

# %%
from sklearn import metrics
print('Mean Absolute Error ',metrics.mean_absolute_error(y_test,y_pred))
# Out:
# Mean Absolute Error  3.095107749617225

# %%
x1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Unit_price                           1000 non-null   Int64
#  1   Quantity                             1000 non-null   Int64
#  2   Product_line_Electronic accessories  1000 non-null   uint8
#  3   Product_line_Fashion accessories     1000 non-null   uint8
#  4   Product_line_Food and beverages      1000 non-null   uint8
#  5   Product_line_Health and beauty       1000 non-null   uint8
#  6   Product_line_Home and lifestyle      1000 non-null   uint8
#  7   Product_line_Sports and travel       1000 non-null   uint8
# dtypes: Int64(2), uint8(6)
# memory usage: 23.6 KB

# %%
x_test
# Out:
#      Unit_price  Quantity  Product_line_Electronic accessories  \
# 993          70         6                                    0
# 859          77         4                                    0
# 298          81         6                                    0
# 553          14         2                                    0
# 672          73         3                                    0
# ..          ...       ...                                  ...
# 679          27         3                                    0
# 722          82         6                                    0
# 215          98         1                                    0
# 653          93         2                                    0
# 150          11         6                                    0
#
#      Product_line_Fashion accessories  Product_line_Food and beverages  \
# 993                                 0                                0
# ...

# %%
val=regressor.predict([[70,6,0,0,0,1,0,0]])[0]
print(val)
# Out:
# 20.718003642958962
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"

# %%
x_test
# Out:
#      Unit_price  Quantity  Tax 5%  Total  cogs  \
# 993          70         6      21    442   421
# 859          77         4      15    325   309
# 298          81         6      24    514   490
# 553          14         2       1     30    29
# 672          73         3      11    231   220
# ..          ...       ...     ...    ...   ...
# 679          27         3       4     85    81
# 722          82         6      24    521   496
# 215          98         1       4    103    98
# 653          93         2       9    195   186
# 150          11         6       3     72    68
#
#      Product_line_Electronic accessories  Product_line_Fashion accessories  \
# 993                                    0                                 0
# 859                                    0                                 0
# 298                                    0                                 0
# 553                                    0                                 0
# ...

# %%
from sklearn.metrics import precision_score, confusion_matrix
#confusion_matrix(y_test, y_pred)
precision_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-edcb4fc5b439> in <module>()
#       1 from sklearn.metrics import precision_score, confusion_matrix
#       2 #confusion_matrix(y_test, y_pred)
# ----> 3 precision_score(y_test, y_pred)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1763         warn_for=("precision",),
#    1764         sample_weight=sample_weight,
# -> 1765         zero_division=zero_division,
#    1766     )
#    1767     return p
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1542     if beta < 0:
# ...
