# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/srinijadharani/Projects-AY21-22/main/07%20Book%20Recommendation%20System/books.csv", error_bad_lines = False)
# Out:
# C:\Users\srini\AppData\Local\Temp\ipykernel_32036\155227974.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv("https://raw.githubusercontent.com/srinijadharani/Projects-AY21-22/main/07%20Book%20Recommendation%20System/books.csv", error_bad_lines = False)
# b'Skipping line 3350: expected 12 fields, saw 13\nSkipping line 4704: expected 12 fields, saw 13\nSkipping line 5879: expected 12 fields, saw 13\nSkipping line 8981: expected 12 fields, saw 13\n'

# %%
len(df)
# Out:
# 11123

# %%
df.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# ...

# %%
df.columns
# Out:
# Index(['bookID', 'title', 'authors', 'average_rating', 'isbn', 'isbn13',
#        'language_code', '  num_pages', 'ratings_count', 'text_reviews_count',
#        'publication_date', 'publisher'],
#       dtype='object')

# %%
df.describe()
# Out:
#              bookID  average_rating        isbn13     num_pages  \
# count  11123.000000    11123.000000  1.112300e+04  11123.000000
# mean   21310.856963        3.934075  9.759880e+12    336.405556
# std    13094.727252        0.350485  4.429758e+11    241.152626
# min        1.000000        0.000000  8.987060e+09      0.000000
# 25%    10277.500000        3.770000  9.780345e+12    192.000000
# 50%    20287.000000        3.960000  9.780582e+12    299.000000
# 75%    32104.500000        4.140000  9.780872e+12    416.000000
# max    45641.000000        5.000000  9.790008e+12   6576.000000
#
#        ratings_count  text_reviews_count
# count   1.112300e+04        11123.000000
# mean    1.794285e+04          542.048099
# std     1.124992e+05         2576.619589
# min     0.000000e+00            0.000000
# 25%     1.040000e+02            9.000000
# 50%     7.450000e+02           47.000000
# 75%     5.000500e+03          238.000000
# max     4.597666e+06        94265.000000

# %%
top_ten = df[df["ratings_count"]>1000000].head(10).sort_values(by="average_rating", ascending = False)

# %%
top_ten
# Out:
#      bookID                                              title  \
# 0         1  Harry Potter and the Half-Blood Prince (Harry ...
# 3         5  Harry Potter and the Prisoner of Azkaban (Harr...
# 1         2  Harry Potter and the Order of the Phoenix (Har...
# 23       34  The Fellowship of the Ring (The Lord of the Ri...
# 299     930                                Memoirs of a Geisha
# 307     960               Angels & Demons (Robert Langdon  #1)
# 514    1618  The Curious Incident of the Dog in the Night-Time
# 294     890                                    Of Mice and Men
# 284     865                                      The Alchemist
# 310     968             The Da Vinci Code (Robert Langdon  #2)
#
#                                       authors  average_rating        isbn  \
# 0                  J.K. Rowling/Mary GrandPré            4.57  0439785960
# 3                  J.K. Rowling/Mary GrandPré            4.56  043965548X
# ...

# %%
# plt.figure(figsize = (10, 10))
# sns.barplot(x = "title", y = "average_rating", data = top_ten)

# %%
plt.figure(figsize = (10, 10))
sns.barplot(x = "average_rating", y = "title", data = top_ten)
# Out:
# <AxesSubplot:xlabel='average_rating', ylabel='title'>

# %%
for i in range(len(df)):
    if df["average_rating"].any() == 5.00:
        print (df[i])
    else:
        print("n")
# Out:
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# n
# ...

# %%
df["language_code"].nunique()
# Out:
# 27

# %%
df["language_code"].unique()
# Out:
# array(['eng', 'en-US', 'fre', 'spa', 'en-GB', 'mul', 'grc', 'enm',
#        'en-CA', 'ger', 'jpn', 'ara', 'nl', 'zho', 'lat', 'por', 'srp',
#        'ita', 'rus', 'msa', 'glg', 'wel', 'swe', 'nor', 'tur', 'gla',
#        'ale'], dtype=object)

# %%
is_5 = [true if df["average_rating"].any() == float(5) else False for i in range(len(df))]

# %%
print(*is_5)
# Out:
# False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False False Fa
# ...

# %%
True in is_5
# Out:
# False

# %%
# avg scores vs no of scores

df.average_rating = df.average_rating.astype(float)
fig, ax = plt.subplots(figsize=[15,10])
sns.kdeplot(df['average_rating'],ax=ax)

# no 5, see?
# Out:
# <AxesSubplot:xlabel='average_rating', ylabel='Density'>

# %%
most_rated = df.sort_values('ratings_count', ascending = False).head(10).set_index('title')
plt.figure(figsize=(15,10))
ax = sns.barplot(most_rated['ratings_count'], most_rated.index, palette = "viridis")

totals = []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)

plt.show()
# Out:
# C:\Users\srinija\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# for preservation
df2 = df.copy()

# %%
# new columns
df2.loc[(df2['average_rating'] >= 0) & (df2['average_rating'] <= 1), 'rating_between'] = "between 0 and 1"
df2.loc[(df2['average_rating'] > 1) & (df2['average_rating'] <= 2), 'rating_between'] = "between 1 and 2"
df2.loc[(df2['average_rating'] > 2) & (df2['average_rating'] <= 3), 'rating_between'] = "between 2 and 3"
df2.loc[(df2['average_rating'] > 3) & (df2['average_rating'] <= 4), 'rating_between'] = "between 3 and 4"
df2.loc[(df2['average_rating'] > 4) & (df2['average_rating'] <= 5), 'rating_between'] = "between 4 and 5"

# %%
rating_df = pd.get_dummies(df2['rating_between'])
language_df = pd.get_dummies(df2['language_code'])

# %%
features = pd.concat([rating_df, language_df, df2["average_rating"], df2["ratings_count"]], axis = 1)

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()
features = min_max_scaler.fit_transform(features)

# %%
from sklearn.cluster import KMeans
from sklearn import neighbors


model = neighbors.NearestNeighbors(n_neighbors=6, algorithm='ball_tree')
model.fit(features)
dist, idlist = model.kneighbors(features)

# %%
book_name = input("Enter book name: ")
def BookRecommender(book_name):
    book_list_name = []
    book_id = df2[df2['title'] == book_name].index
    book_id = book_id[0]
    for newid in idlist[book_id]:
        book_list_name.append(df2.loc[newid].title)
    return book_list_name
    
BookNames = BookRecommender(book_name)
BookNames
# Out:
# Enter book name: dipshit
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-170-cbee4e482da1> in <module>
#       8     return book_list_name
#       9
# ---> 10 BookNames = BookRecommender(book_name)
#      11 BookNames
#
# <ipython-input-170-cbee4e482da1> in BookRecommender(book_name)
#       3     book_list_name = []
#       4     book_id = df2[df2['title'] == book_name].index
# ----> 5     book_id = book_id[0]
#       6     for newid in idlist[book_id]:
#       7         book_list_name.append(df2.loc[newid].title)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    4099         if is_scalar(key):
#    4100             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4101             return getitem(key)
#    4102
#    4103         if isinstance(key, slice):
#
# ...

# %%
BookNames = BookRecommender("Memoirs of a Geisha")
BookNames
# Out:
# ['Memoirs of a Geisha',
#  'Nineteen Minutes',
#  'Stardust',
#  "1st to Die (Women's Murder Club  #1)",
#  'The Unbearable Lightness of Being',
#  'Snow Flower and the Secret Fan']

# %%
BookNames = BookRecommender("Poor People")
BookNames
# Out:
# ['Poor People',
#  "The Catcher in the Rye - Barron's Book Notes",
#  'The Girl in the Glass',
#  'Exemplary Stories',
#  'RG Veda  Vol. 01',
#  'Fire Lover: A True Story']

# %%
BookNames = BookRecommender("The Lord of the Rings")
BookNames
# Out:
# ['Thucydides  Book 6 Commentary',
#  '1968: War and Democracy',
#  'Interviews with John Kenneth Galbraith (Conversations with Public Intellectuals)',
#  'The Play Soldier',
#  "Children's Christmas Stories and Poems: In Easy-to-Read Type",
#  'The Lord of the Rings']

# %%
BookNames = BookRecommender("The Two Towers (The Lord of the Rings  #2)")
BookNames
# Out:
# ['The Two Towers (The Lord of the Rings  #2)',
#  'A Clash of Kings  (A Song of Ice and Fire  #2)',
#  'Matilda',
#  'And Then There Were None',
#  'Anne of Green Gables (Anne of Green Gables  #1)',
#  'The Count of Monte Cristo']

# %%
# shorten the title - make the search easier. 
# more accurate if the titles are precise, but it's tedious. dont you think?

# %%
BookNames = BookRecommender("Matilda")
BookNames
# Out:
# ['Matilda',
#  'And Then There Were None',
#  'Anne of Green Gables (Anne of Green Gables  #1)',
#  'Crime and Punishment',
#  'The Sea of Monsters (Percy Jackson and the Olympians  #2)',
#  'The Count of Monte Cristo']

# %%
BookNames = BookRecommender("And Then There Were None")
BookNames
# Out:
# ['And Then There Were None',
#  'Anne of Green Gables (Anne of Green Gables  #1)',
#  'The Sea of Monsters (Percy Jackson and the Olympians  #2)',
#  'The Count of Monte Cristo',
#  'Outlander (Outlander  #1)',
#  'The Princess Bride']

# %%
BookNames = BookRecommender("The Wizard")
BookNames
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-167-40ec7070e06e> in <module>
# ----> 1 BookNames = BookRecommender("The Wizard")
#       2 BookNames
#
# <ipython-input-149-8afef7a92393> in BookRecommender(book_name)
#       2     book_list_name = []
#       3     book_id = df2[df2['title'] == book_name].index
# ----> 4     book_id = book_id[0]
#       5     for newid in idlist[book_id]:
#       6         book_list_name.append(df2.loc[newid].title)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    4099         if is_scalar(key):
#    4100             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4101             return getitem(key)
#    4102
#    4103         if isinstance(key, slice):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
book_name = input()
def BookRecommender(book_name):
    book_list_name = []
    book_id = df2[df2['title'] == book_name].index
    book_id = book_id[0]
    for newid in idlist[book_id]:
        book_list_name.append(df2.loc[newid].title)
    return book_list_name
    
BookNames = BookRecommender(book_name)
BookNames
# Out:
# The Right Stuff
# ['The Right Stuff',
#  'The Perfect Wrong Note: Learning to Trust Your Musical Self',
#  'The Selected Journals Of L.M. Montgomery  Vol. 5: 1935-1942',
#  'Baseball: a Literary Anthology',
#  'Children of the Star (Children of the Star  #1-3)',
#  'Diana Vreeland']
